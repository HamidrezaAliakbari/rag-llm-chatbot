# %% [markdown]
# # Week 1 – RAG Q&A Chatbot
#
# **Outline:**
# - Ingest PDFs/webpages
# - Chunk & embed text
# - Store vectors (FAISS/Chroma)
# - Build LangChain retrieval chain
# - Demo Q&A with citations
